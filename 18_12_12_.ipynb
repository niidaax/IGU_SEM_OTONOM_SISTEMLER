# %% [markdown]
# <a href="https://colab.research.google.com/github/niidaax/IGU_SEM_OTONOM_SISTEMLER/blob/main/18_12_12_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Ders_no = 4
pi_sayisi = 3.14159
Dersin_ismi = "Python - Veri Yapıları Ve Algoritmalar"
#Veri Türü
durum1 = True
durum2 = False

print(Ders_no)
print(pi_sayisi)
print(Dersin_ismi)
print(durum1)
print(durum2)
# Out:
# 4
# 3.14159
# Python - Veri Yapıları Ve Algoritmalar
# True
# False

# %%
a = 7
b = 3
print(a + b)
# Out:
# 10

# %%
a = 7
b = 3
print("Çarpma:", a*b)
print("Üs Alma:", a**b)
print("Mod:", a % b)
# Out:
# Toplama: 21
# Üs Alma: 343
# Mod: 1

# %%
a = 7
b = 3
print("a==b", a==b)
print("a<b:", a<b)
print("a>b:", a>b)
# Out:
# a==b False
# a<b: False
# a>b: True

# %%
a=True
b=False
print("a and b:", a and b)
print("a or b:", a or b)
print("not a:", not a)
print("not b:", not b)
# Out:
# a and b: False
# a or b: True
# not a: False
# not b: True

# %%
x = 7
x += 3
print(x)
# Out:
# 10

# %%
print(7 & 3)
print(7 | 3)
print(7 ^ 3)
print(7 << 3)
# Out:
# 3
# 7
# 4
# 56

# %% [markdown]
# if yapısı örneği:

# %%
a = 10
if a > 0:
   a = a + 1
   print(a)
# Out:
# 11

# %%
a = 5
b = 4
c = 0
if a>0 and b>0:
  c=a*b +b
  print(c)
# Out:
# 24

# %%
a = 5
b = 4
c = 0
if a>0 and b>0:
  c=a+b
  c=a*a + c
  print(c)
# Out:
# 34

# %%
a = 4
b = 1
if a>b:
  print(a)
else:
   print(b)
# Out:
# 4

# %%
if ifade1:
  #ifade 1 için 'durum1' işlemler bloğu
elif ifade2:
  #ifade 2 için 'durum2' işlemler bloğu
elif ifade3:
  #ifade 3 için 'durum1' işlemler bloğu
else
#tüm ifadeler dışındaki 'durum4' işlemler bloğu

# %%
degisken = 0
sonuc = 0
if degisken == 1:
  sonuc += 1
  print(sonuc)
elif degisken == 2:
  sonuc += 2
  print(sonuc)
elif degisken == 3:
  sonuc += 3
  print(sonuc)
else:
  sonuc= 0
  print(sonuc)
# Out:
# 0

# %%
for i in range(1, 11 + 1) :
  print('Sayi_Listesi:', i)
# Out:
# Sayi_Listesi: 1
# Sayi_Listesi: 2
# Sayi_Listesi: 3
# Sayi_Listesi: 4
# Sayi_Listesi: 5
# Sayi_Listesi: 6
# Sayi_Listesi: 7
# Sayi_Listesi: 8
# Sayi_Listesi: 9
# Sayi_Listesi: 10
# Sayi_Listesi: 11

# %%
for ch in range(ord('A'), ord('Z')+1):
  print('alfabe listesi:', chr(ch))
# Out:
# alfabe listesi: A
# alfabe listesi: B
# alfabe listesi: C
# alfabe listesi: D
# alfabe listesi: E
# alfabe listesi: F
# alfabe listesi: G
# alfabe listesi: H
# alfabe listesi: I
# alfabe listesi: J
# alfabe listesi: K
# alfabe listesi: L
# alfabe listesi: M
# alfabe listesi: N
# alfabe listesi: O
# alfabe listesi: P
# alfabe listesi: Q
# alfabe listesi: R
# alfabe listesi: S
# alfabe listesi: T
# alfabe listesi: U
# alfabe listesi: V
# alfabe listesi: W
# alfabe listesi: X
# alfabe listesi: Y
# alfabe listesi: Z

# %%
x=3
c=0
while c<3:
  print('ekran cıktısı:', c,x)
  x=x*x
  c=c+1
  print('döngü sonu:',c,x)
# Out:
# ekran cıktısı: 0 3
# döngü sonu: 1 9
# ekran cıktısı: 1 9
# döngü sonu: 2 81
# ekran cıktısı: 2 81
# döngü sonu: 3 6561

# %%
sayac=4
while sayac*sayac<=1000:
  print('döngü sonu:', sayac)
  sayac +=1
# Out:
# döngü sonu: 4
# döngü sonu: 5
# döngü sonu: 6
# döngü sonu: 7
# döngü sonu: 8
# döngü sonu: 9
# döngü sonu: 10
# döngü sonu: 11
# döngü sonu: 12
# döngü sonu: 13
# döngü sonu: 14
# döngü sonu: 15
# döngü sonu: 16
# döngü sonu: 17
# döngü sonu: 18
# döngü sonu: 19
# döngü sonu: 20
# döngü sonu: 21
# döngü sonu: 22
# döngü sonu: 23
# döngü sonu: 24
# döngü sonu: 25
# döngü sonu: 26
# döngü sonu: 27
# döngü sonu: 28
# döngü sonu: 29
# döngü sonu: 30
# döngü sonu: 31

# %% [markdown]
# Girilen sayının 5in kuvveti olup olmadığını bulan algoritma

# %%
sayi= int(input("Bir sayı girin:"))
if sayi %5 == 0:
  print("5'in kuvvetidir.")
else:
    print("5'in kati değildir.")
# Out:
# Bir sayı girin:27
# 5'in kati değildir.

# %% [markdown]
# Girilen yılın artık yıl olup olmadığını bulan programın algoritması

# %%
yil = int(input("Bir yıl girin:"))
if yil % 4 == 0:
  print("Artık yıldır.")
else:
  print("Artık yıl değildir.")
# Out:
# Bir yıl girin:30
# Artık yıl değildir.

# %% [markdown]
# Klavyeden 0 girilinceye kadar sayı girilmesini sağlayan ve bu sayıların kaç tane olduğu, sayıların toplamı ve ortalama sonuçlarını ekrana yazdıran algoritma

# %%
sayi =1
s = 1
toplam = 0
while sayi != 0:
  sayi= int(input("Bir sayı girin. (0 ile çıkabilirsiniz):"))
  if sayi != 0:
    toplam += sayi
    s+=1
  if s == 0:
    print("Sayi girisi yapmadınız!!")
  else:
    ort = toplam /s
    print(s, "tane sayı girilmiştir.")
    print(toplam)
    print(ortalama)
# Out:
# Bir sayı girin. (0 ile çıkabilirsiniz):1
# 2 tane sayı girilmiştir.
# 1
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-350093462.py in <cell line: 0>()
#      13     print(s, "tane sayı girilmiştir.")
#      14     print(toplam)
# ---> 15     print(ortalama)
#
# NameError: name 'ortalama' is not defined

# %% [markdown]
# Liste Veri Tipi Örneği

# %%
sayilar = [10, 20, 30, 40, 50]

#toplam hesaplama
toplam = sum(sayilar)
print("Toplam:", toplam)

#maksimum ve minimum değer bulma
print("EN BÜYÜK SAYI:", max(sayilar))
print("EN KÜÇÜK SAYI:", min(sayilar))
# Out:
# Toplam: 150
# EN BÜYÜK SAYI: 50
# EN KÜÇÜK SAYI: 10

# %% [markdown]
# Sözlük veri tipi örneği

# %%
ogrenci = {
    "isim": "Nida",
    "yaş": 21,
    "ders": "Python Programlama",
    "not": "90"
}

#Bilgilerin yazdırılması
print("Öğrenci Bilgiler:")
for anahtar, deger in ogrenci.items():
  print(anahtar, deger)
# Out:
# Öğrenci Bilgiler:
# isim Nida
# yaş 21
# ders Python Programlama
# not 90
